# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train_data = pd.read_csv('Dataset/train.csv')

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data['Age'].isnull().sum()
# Out:
# 177

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train_data['Sex'] = train_data['Sex'].astype('category')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null category
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: category(1), float64(2), int64(5), object(4)
# memory usage: 77.6+ KB

# %%
train_data = train_data.set_index('PassengerId')

# %%
train_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
train_data.shape
# Out:
# (891, 11)

# %%
datamiss = pd.DataFrame(train_data.dtypes)

# %%
datamiss['Miss Value'] = train_data.isnull().sum()

# %%
datamiss
# Out:
#                  0  Miss Value
# Survived     int64           0
# Pclass       int64           0
# Name        object           0
# Sex       category           0
# Age        float64         177
# SibSp        int64           0
# Parch        int64           0
# Ticket      object           0
# Fare       float64           0
# Cabin       object         687
# Embarked    object           2

# %%
datamiss['nUnique'] = train_data.nunique()

# %%
datamiss
# Out:
#                  0  Miss Value  nUnique
# Survived     int64           0        2
# Pclass       int64           0        3
# Name        object           0      891
# Sex       category           0        2
# Age        float64         177       88
# SibSp        int64           0        7
# Parch        int64           0        7
# Ticket      object           0      681
# Fare       float64           0      248
# Cabin       object         687      147
# Embarked    object           2        3

# %%
datamiss['count'] = train_data.count()

# %%
datamiss
# Out:
#                  0  Miss Value  nUnique  count
# Survived     int64           0        2    891
# Pclass       int64           0        3    891
# Name        object           0      891    891
# Sex       category           0        2    891
# Age        float64         177       88    714
# SibSp        int64           0        7    891
# Parch        int64           0        7    891
# Ticket      object           0      681    891
# Fare       float64           0      248    891
# Cabin       object         687      147    204
# Embarked    object           2        3    889

# %%
train_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
datamiss.rename(columns={0:'Data Type'})
# Out:
#          Data Type  Miss Value  nUnique  count
# Survived     int64           0        2    891
# Pclass       int64           0        3    891
# Name        object           0      891    891
# Sex       category           0        2    891
# Age        float64         177       88    714
# SibSp        int64           0        7    891
# Parch        int64           0        7    891
# Ticket      object           0      681    891
# Fare       float64           0      248    891
# Cabin       object         687      147    204
# Embarked    object           2        3    889

# %%
train_data.describe(include='object')
# Out:
#                              Name Ticket    Cabin Embarked
# count                         891    891      204      889
# unique                        891    681      147        3
# top     Dodge, Master. Washington   1601  B96 B98        S
# freq                            1      7        4      644

# %%
train_data.describe(include='number')
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train_data.describe(include='category')
# Out:
#          Sex
# count    891
# unique     2
# top     male
# freq     577

# %%
train_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ### Univariate and Mulitvariate analysis

# %%
sns.countplot(x='Survived', data=train_data)

# %%
train_data.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.set_style("whitegrid");
sns.pairplot(train_data, hue="Survived", size=3);
plt.show()
# Out:
# C:\Users\tejakummarikuntla\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\tejakummarikuntla\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\tejakummarikuntla\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\tejakummarikuntla\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\tejakummarikuntla\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
# ...

# %%
sns.boxplot(x='Survived',y='Age', data=train_data)
plt.show()

# %%
train_data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
train_data['Survived'].value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %% [markdown]
# only 38% of the passengers were survived, where as a majority 61% the passenger did not survive the disaster

# %%
print("% of Women Survived :",train_data[train_data.Sex == 'female'].Survived.sum() / train_data[train_data.Sex == 'female'].Survived.count())

print("% of Men Survived: ", train_data[train_data.Sex == 'male'].Survived.sum() / train_data[train_data.Sex == 'male'].Survived.count())
# Out:
# % of Women Survived : 0.7420382165605095
# % of Men Survived:  0.18890814558058924

# %%
train_data[train_data.Sex == 'female'].Survived.count()
# Out:
# 314

# %%
sns.catplot(x='Sex', col='Survived', kind='count', data=train_data)

# %%
train_data.groupby(['Survived', 'Sex'])['Survived'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64
